# %%
import numpy as np
import pandas as pd
import whyqd as _w

# %%
schema = _w.Schema()
details = {
    'name' : 'economic-performance',
    'title' : 'indicateur de performance economique des pays dans le monde',
    'description' : 'ce document présente les valeurs d\'indicateurs tels que le PIB en valeur ou en PPP de divers pays dans le monde.'
}
schema.set_details(**details)

# %%
fields = [
    {
        'name' : 'Country_Name',
        'title' : 'Country_name',
        'type' : 'string',
        'description' : 'Noms des différents pays représentant les individus dans la base de données',
        'constraints' : {
            'required' : True
        }
    },
    {
        'name' : 'HDI_category',
        'title' : 'HDI_category',
        'type' : 'string',
        'description' : 'la catégorie selon le rang d\'IDH',
    },
    {
        'name' : 'Indicator Name',
        'title' : 'Indicator Name',
        'type' : 'string',
        'description' : 'Description des indicateurs présents dans la base de données',
    },
    {
        'name' : 'References',
        'title' : 'References',
        'type' : 'string',
        'description' : 'les references dans la base de données',
    },
    {
        'name' : 'Year',
        'title' : 'Year',
        'type' : 'year',
        'description' : 'date d\'enregistrement de l\'indicateur',
    },
    {
        'name' : 'Values',
        'tite' : 'Values',
        'type' : 'number',
        'description' : 'valeur de l\'indicateur selon le nom du pays et l\'année',
        'constraints':{
            'required' : True
        }
    },
]
for field in fields:
    schema.set_field(**field)

# %%
schema.field('country_name')
# Out:
# {'name': 'country_name',
#  'type': 'string',
#  'constraints': {'required': True},
#  'title': 'Country_name',
#  'description': 'Noms des différents pays représentant les individus dans la base de données'}

# %%
directory = 'SBC4D_course_2-2/'
file_name = 'economic_performance_schema'
schema.save(directory , filename = file_name, overwrite = True)
# Out:
# True

# %%
from IPython.core.display import HTML
display(HTML('<style>pre { white-space: pre !important; }</style>'))
SCHEMA_SOURCE = 'SBC4D_course_2-2/economic_performance_schema.json'
DIRECTORY = './SBC4D_course_2-2/'
INPUT_DATA = ['./HDR 2007-2008 Table 14.xlsx']
method = _w.Method(SCHEMA_SOURCE, directory = DIRECTORY, input_data = INPUT_DATA)
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
print(method.help())
# Out:
# **whyqd** provides data wrangling simplicity, complete audit transparency, and at speed.
#
# To get help, type:
#
# 	>>> method.help(option)
#
# Where `option` can be any of:
#
# 	status
# 	merge
# 	structure
# 	category
# 	filter
# 	transform
#
# `status` will return the current method status, and your mostly likely next steps. The other options
# will return methodology, and output of that option's result (if appropriate). The `error` will
# present an error trace and attempt to guide you to fix the process problem.
#
# Current method status: `Ready to Merge`

# %%
print(method.print_input_data())
# Out:
# Data id: eaee5ac0-3403-4bec-9c0e-97f61615a75f
# Original source: ./HDR 2007-2008 Table 14.xlsx
#
# ====  ========================  ============  ============  ==================================================================================  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============
#   ..  Unnamed: 0                  Unnamed: 1    Unnamed: 2  Unnamed: 3                                                                            Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9    Unnamed: 10    Unnamed: 11    Unnamed: 12    Unnamed: 13    Unnamed: 14    Unnamed: 15    Unnamed: 16    Unnamed: 17    Unnamed: 18    Unnamed: 19    Unnamed: 20    Unnamed: 21    Unnamed: 22    Unnamed: 23    Unnamed: 24    Unnamed: 25    Unnamed: 26    Unnamed: 27    Unnamed: 28    Unnamed: 29    Unnamed: 30    Unnamed: 31    Unnamed: 32
# ====  ========================  ============  ============  ==================================================================================  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============
#    0  nan                                nan           nan  . . . to have access to the resources needed for a decent standard of living . . .           nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
#    1  nan                                nan           nan  nan                                                                                          nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
#    2  14  Economic performance           nan           nan  nan                                                                                          nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
# ====  ========================  ============  ============  ==================================================================================  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============

# %%
method.default_morph_types
# Out:
# ['CATEGORISE', 'DEBLANK', 'DEDUPE', 'DELETE', 'MELT', 'REBASE', 'RENAME']

# %%
method.default_morph_settings("CATEGORISE")
# Out:
# {'name': 'CATEGORISE',
#  'title': 'Categorise',
#  'type': 'morph',
#  'description': 'Convert row-level categories into column categorisations.',
#  'structure': ['rows', 'column_names']}

# %%
ident = method.input_data[0]['id']
df = method.input_dataframe(ident)
df.head(10)
# Out:
#                  Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                       NaN        NaN        NaN
# 1                       NaN        NaN        NaN
# 2  14  Economic performance        NaN        NaN
# 3                       NaN        NaN        NaN
# 4                       NaN        NaN        NaN
# 5                       NaN        NaN        NaN
# 6                       NaN        NaN        NaN
# 7                  HDI rank        NaN        NaN
# 8    HIGH HUMAN DEVELOPMENT        NaN        NaN
# 9                         1    Iceland        NaN
#
#                                           Unnamed: 3 Unnamed: 4  \
# 0  . . . to have access to the resources needed f...        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN
# 5                                                GDP        NaN
# 6                                                GDP        NaN
# 7                                 US$ billions\n2005        NaN
# 8                                                NaN        NaN
# 9                                               15.8        NaN
#
#                 Unnamed: 5 Unnamed: 6      Unnamed: 7 Unnamed: 8  \
# 0                      NaN        NaN             NaN        NaN
# 1                      NaN        NaN             NaN        NaN
# 2                      NaN        NaN             NaN        NaN
# 3                      NaN        NaN             NaN        NaN
# 4                      NaN        NaN  GDP per capita        NaN
# 5                      NaN        NaN             NaN        NaN
# 6                      NaN        NaN             NaN        NaN
# 7   PPP US$ billions\n2005        NaN       US$\n2005        NaN
# 8                      NaN        NaN             NaN        NaN
# 9                     10.8        NaN          53,290        NaN
#
#             Unnamed: 9  ... Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 0                  NaN  ...         NaN         NaN         NaN         NaN
# 1                  NaN  ...         NaN         NaN         NaN         NaN
# 2                  NaN  ...         NaN         NaN         NaN         NaN
# 3                  NaN  ...         NaN         NaN         NaN         NaN
# 4                  NaN  ...         NaN         NaN         NaN         NaN
# 5                  NaN  ...         NaN         NaN         NaN         NaN
# 6                  NaN  ...         NaN         NaN         NaN         NaN
# 7  2005 PPP US$a\n2005  ...         NaN         NaN         NaN         NaN
# 8                  NaN  ...         NaN         NaN         NaN         NaN
# 9               36,510  ...         NaN         NaN         NaN         NaN
#
#   Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
# 5         NaN         NaN         NaN         NaN         NaN         NaN
# 6         NaN         NaN         NaN         NaN         NaN         NaN
# 7         NaN         NaN         NaN         NaN         NaN         NaN
# 8         NaN         NaN         NaN         NaN         NaN         NaN
# 9         NaN         NaN         NaN         NaN         NaN         NaN
#
# [10 rows x 33 columns]

# %%
method.reset_input_data_morph(ident)

# %%
method.add_input_data_morph(ident, ['REBASE', 7])

# %%
rows = [int(i) for i in np.arange(188, df.index[-1]+1)]
method.add_input_data_morph(ident, ["DELETE", rows])

# %%
columns = [
    "HDI rank",
    "Country",
    "GDP - billions dollar US 2005",
    "References 1",
    "GDP - PPP billions dollar US 2005",
    "References 2",
    "GDP per capita - US 2005",
    "References 3",
    "GDP per capita - 2005 PPP dollar US 2005",
    "References 4",
    "GDP per capita - Annual growth rate(percent) 1975-2005",
    "References 5",
    "GDP per capita - Annual growth rate(percent) 1990-2005",
    "References 6",
    "GDP per capita - highest value during 1975-2005 2005 PPP US$",
    "References 7",
    "GDP per capita - year of highest value",
    "Average annual change in consumer price index(percent) - 1990-2005",
    "Average annual change in consumer price index(percent) - 2004-2005"
]
method.add_input_data_morph(ident, ['RENAME', columns])

# %%
df = method.input_dataframe(ident)
df.head()
# Out:
#                   HDI rank    Country GDP - billions dollar US 2005  \
# 8   HIGH HUMAN DEVELOPMENT        NaN                           NaN
# 9                        1    Iceland                          15.8
# 10                       2     Norway                         295.5
# 11                       3  Australia                         732.5
# 12                       4     Canada                       1,113.8
#
#    References 1 GDP - PPP billions dollar US 2005 References 2  \
# 8           NaN                               NaN          NaN
# 9           NaN                              10.8          NaN
# 10          NaN                             191.5          NaN
# 11          NaN                             646.3          NaN
# 12          NaN                           1,078.0          NaN
#
#    GDP per capita - US 2005 References 3  \
# 8                       NaN          NaN
# 9                    53,290          NaN
# 10                   63,918          NaN
# 11                   36,032          NaN
# 12                   34,484          NaN
#
#    GDP per capita - 2005 PPP dollar US 2005 References 4  \
# 8                                       NaN          NaN
# 9                                    36,510          NaN
# 10                                   41,420          NaN
# 11                                   31,794          NaN
# 12                                   33,375          NaN
#
#    GDP per capita - Annual growth rate(percent) 1975-2005 References 5  \
# 8                                                 NaN              NaN
# 9                                                 1.8              NaN
# 10                                                2.6              NaN
# 11                                                2.0              NaN
# 12                                                1.6              NaN
#
#    GDP per capita - Annual growth rate(percent) 1990-2005 References 6  \
# 8                                                 NaN              NaN
# 9                                                 2.2              NaN
# 10                                                2.7              NaN
# 11                                                2.5              NaN
# 12                                                2.2              NaN
#
#    GDP per capita - highest value during 1975-2005 2005 PPP US$ References 7  \
# 8                                                 NaN                    NaN
# 9                                              36,510                    NaN
# 10                                             41,420                    NaN
# 11                                             31,794                    NaN
# 12                                             33,375                    NaN
#
#    GDP per capita - year of highest value  \
# 8                                     NaN
# 9                                    2005
# 10                                   2005
# 11                                   2005
# 12                                   2005
#
#    Average annual change in consumer price index(percent) - 1990-2005  \
# 8                                                 NaN
# 9                                                 3.3
# 10                                                2.2
# 11                                                2.5
# 12                                                1.9
#
#    Average annual change in consumer price index(percent) - 2004-2005
# 8                                                 NaN
# 9                                                 4.2
# 10                                                1.5
# 11                                                2.7
# 12                                                2.2

# %%
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
rows = df[df["HDI rank"].isin(hdi_categories)].index
method.add_input_data_morph(ident, ["CATEGORISE", rows, "HDI category"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-fff1bc6c7961> in <module>
#       1 hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
#       2 rows = df[df["HDI rank"].isin(hdi_categories)].index
# ----> 3 method.add_input_data_morph(ident, ["CATEGORISE", rows, "HDI category"])
#
# ~/anaconda3/lib/python3.7/site-packages/whyqd/method/method.py in add_input_data_morph(self, _id, new_morph)
#    1128                         input_source = self._get_input_data_morph(_id)
#    1129                 df = self.input_dataframe(_id)
# -> 1130                 input_source["morph"] = self.add_morph(df=df, new_morph=new_morph, morph_methods=input_source.get("morph"))
#    1131                 self._set_input_data_morph(input_source)
#    1132
#
# ~/anaconda3/lib/python3.7/site-packages/whyqd/method/method.py in add_morph(self, df, new_morph, morph_methods)
#    1251                 if not morph.validates(df=df, **parameters):
#    1252                         e = F"Task morph `{morph.name}` has invalid structure `{morph.structure}`."
# -> 1253                         raise ValueError(e)
#    1254                 morph_settings = morph.settings
#    1255                 morph_settings["id"] = str(uuid.uuid4())
#
# ValueError: Task morph `CATEGORISE` has invalid structure `['rows', 'column_names']`.

# %%
type(rows)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
method.add_input_data_morph(ident, ["CATEGORISE", list(rows), "HDI category"])

# %%
df = method.input_dataframe(ident)
df.head(200)
# Out:
#     HDI rank        Country GDP - billions dollar US 2005 References 1  \
# 9          1        Iceland                          15.8          NaN
# 10         2         Norway                         295.5          NaN
# 11         3      Australia                         732.5          NaN
# 12         4         Canada                       1,113.8          NaN
# 13         5        Ireland                         201.8          NaN
# ..       ...            ...                           ...          ...
# 183      173           Mali                           5.3          NaN
# 184      174          Niger                           3.4          NaN
# 185      175  Guinea-Bissau                           0.3          NaN
# 186      176   Burkina Faso                           5.2          NaN
# 187      177   Sierra Leone                           1.2          NaN
#
#     GDP - PPP billions dollar US 2005 References 2 GDP per capita - US 2005  \
# 9                                10.8          NaN                   53,290
# 10                              191.5          NaN                   63,918
# 11                              646.3          NaN                   36,032
# 12                            1,078.0          NaN                   34,484
# 13                              160.1          NaN                   48,524
# ..                                ...          ...                      ...
# 183                              14.0          NaN                      392
# 184                              10.9            d                      244
# 185                               1.3            d                      190
# 186                              16.0            d                      391
# 187                               4.5          NaN                      216
#
#     References 3 GDP per capita - 2005 PPP dollar US 2005 References 4  \
# 9            NaN                                   36,510          NaN
# 10           NaN                                   41,420          NaN
# 11           NaN                                   31,794          NaN
# 12           NaN                                   33,375          NaN
# 13           NaN                                   38,505          NaN
# ..           ...                                      ...          ...
# 183          NaN                                    1,033          NaN
# 184          NaN                                      781            d
# 185          NaN                                      827            d
# 186          NaN                                    1,213            d
# 187          NaN                                      806          NaN
#
#     GDP per capita - Annual growth rate(percent) 1975-2005 References 5  \
# 9                                                  1.8              NaN
# 10                                                 2.6              NaN
# 11                                                 2.0              NaN
# 12                                                 1.6              NaN
# 13                                                 4.5              NaN
# ..                                                 ...              ...
# 183                                                0.2              NaN
# 184                                               -1.7              NaN
# 185                                               -0.6              NaN
# 186                                                0.9              NaN
# 187                                               -2.1              NaN
#
#     GDP per capita - Annual growth rate(percent) 1990-2005 References 6  \
# 9                                                  2.2              NaN
# 10                                                 2.7              NaN
# 11                                                 2.5              NaN
# 12                                                 2.2              NaN
# 13                                                 6.2              NaN
# ..                                                 ...              ...
# 183                                                2.2              NaN
# 184                                               -0.5              NaN
# 185                                               -2.6              NaN
# 186                                                1.3              NaN
# 187                                               -1.4              NaN
#
#     GDP per capita - highest value during 1975-2005 2005 PPP US$ References 7  \
# 9                                               36,510                    NaN
# 10                                              41,420                    NaN
# 11                                              31,794                    NaN
# 12                                              33,375                    NaN
# 13                                              38,505                    NaN
# ..                                                 ...                    ...
# 183                                              1,033                    NaN
# 184                                              1,293                    NaN
# 185                                              1,264                    NaN
# 186                                              1,213                    NaN
# 187                                              1,111                    NaN
#
#     GDP per capita - year of highest value  \
# 9                                     2005
# 10                                    2005
# 11                                    2005
# 12                                    2005
# 13                                    2005
# ..                                     ...
# 183                                   2005
# 184                                   1979
# 185                                   1997
# 186                                   2005
# 187                                   1982
#
#     Average annual change in consumer price index(percent) - 1990-2005  \
# 9                                                  3.3
# 10                                                 2.2
# 11                                                 2.5
# 12                                                 1.9
# 13                                                 2.9
# ..                                                 ...
# 183                                                3.8
# 184                                                4.4
# 185                                               20.2
# 186                                                4.1
# 187                                               19.7
#
#     Average annual change in consumer price index(percent) - 2004-2005  \
# 9                                                  4.2
# 10                                                 1.5
# 11                                                 2.7
# 12                                                 2.2
# 13                                                 2.4
# ..                                                 ...
# 183                                                6.4
# 184                                                7.8
# 185                                                3.3
# 186                                                6.4
# 187                                               12.1
#
#                HDI category
# 9    HIGH HUMAN DEVELOPMENT
# 10   HIGH HUMAN DEVELOPMENT
# 11   HIGH HUMAN DEVELOPMENT
# 12   HIGH HUMAN DEVELOPMENT
# 13   HIGH HUMAN DEVELOPMENT
# ..                      ...
# 183                     NaN
# 184                     NaN
# 185                     NaN
# 186                     NaN
# 187                     NaN
#
# [177 rows x 20 columns]

# %%
columns = [
    "HDI rank",
    "GDP - billions dollar US 2005",
    "GDP - PPP billions dollar US 2005",
    "GDP per capita - US 2005",
    "GDP per capita - 2005 PPP dollar US 2005",
    "GDP per capita - Annual growth rate(percent) 1975-2005",
    "GDP per capita - Annual growth rate(percent) 1990-2005",
    "GDP per capita - highest value during 1975-2005 2005 PPP US$",
    "Average annual change in consumer price index(percent) - 1990-2005",
    "Average annual change in consumer price index(percent) - 2004-2005"
]
method.add_input_data_morph(ident, ['MELT', columns, ['Indicator Name', 'Indicator Value']])

# %%
columns = [
    "References 1",
    "References 2",
    "References 3",
    "References 4",
    "References 5",
    "References 6",
    "References 7",
]
method.add_input_data_morph(ident,['MELT', columns, ['Reference Name', 'Reference']])

# %%
method.add_input_data_morph(ident, ['DEBLANK'])

# %%
df = method.input_dataframe(ident)
df.head()
# Out:
#   GDP per capita - year of highest value Indicator Name    Country  \
# 0                                   2005       HDI rank    Iceland
# 1                                   2005       HDI rank     Norway
# 2                                   2005       HDI rank  Australia
# 3                                   2005       HDI rank     Canada
# 4                                   2005       HDI rank    Ireland
#
#              HDI category Indicator Value Reference Name Reference
# 0  HIGH HUMAN DEVELOPMENT               1   References 1       NaN
# 1  HIGH HUMAN DEVELOPMENT               2   References 1       NaN
# 2  HIGH HUMAN DEVELOPMENT               3   References 1       NaN
# 3  HIGH HUMAN DEVELOPMENT               4   References 1       NaN
# 4  HIGH HUMAN DEVELOPMENT               5   References 1       NaN

# %%
print(method.help("merge"))
# Out:
# `merge` will join, in order from right to left, your input data on a common column.
#
# To add input data, where `input_data` is a filename, or list of filenames:
#
# 	>>> method.add_input_data(input_data)
#
# To remove input data, where `id` is the unique id for that input data:
#
# 	>>> method.remove_input_data(id)
#
# Prepare an `order_and_key` list, where each dict in the list has:
#
# 	{{id: input_data id, key: column_name for merge}}
#
# Run the merge by calling (and, optionally - if you need to overwrite an existing merge - setting
# `overwrite_working=True`):
#
# 	>>> method.merge(order_and_key, overwrite_working=True)
#
# To view your existing `input_data`:
#
# 	>>> method.input_data
#
#
# Data id: eaee5ac0-3403-4bec-9c0e-97f61615a75f
# Original source: ./HDR 2007-2008 Table 14.xlsx
#
# ====  ========================  ============  ============  ==================================================================================  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============
#   ..  Unnamed: 0                  Unnamed: 1    Unnamed: 2  Unnamed: 3                                                                            Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9    Unnamed: 10    Unnamed: 11    Unnamed: 12    Unnamed: 13    Unnamed: 14    Unnamed: 15    Unnamed: 16    Unnamed: 17    Unnamed: 18    Unnamed: 19    Unnamed: 20    Unnamed: 21    Unnamed: 22    Unnamed: 23    Unnamed: 24    Unnamed: 25    Unnamed: 26    Unnamed: 27    Unnamed: 28    Unnamed: 29    Unnamed: 30    Unnamed: 31    Unnamed: 32
# ====  ========================  ============  ============  ==================================================================================  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============
#    0  nan                                nan           nan  . . . to have access to the resources needed for a decent standard of living . . .           nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
#    1  nan                                nan           nan  nan                                                                                          nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
#    2  14  Economic performance           nan           nan  nan                                                                                          nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
# ====  ========================  ============  ============  ==================================================================================  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============
#
#
# Current method status: `Ready to Merge`

# %%
# %time method.merge(overwrite_working=True)
# Out:
# CPU times: user 4.59 s, sys: 44.1 ms, total: 4.63 s
# Wall time: 4.81 s

# %%
print(method.help("structure"))
# Out:
# `structure` is the core of the wrangling process and is the process where you define the actions
# which must be performed to restructure your working data.
#
# Create a list of methods of the form:
#
# 	{
# 		"schema_field1": ["action", "column_name1", ["action", "column_name2"]],
# 		"schema_field2": ["action", "column_name1", "modifier", ["action", "column_name2"]],
# 	}
#
# The format for defining a `structure` is as follows::
#
# 	[action, column_name, [action, column_name]]
#
# e.g.::
#
# 	["CATEGORISE", "+", ["ORDER", "column_1", "column_2"]]
#
# This permits the creation of quite expressive wrangling structures from simple building
# blocks.
#
# The schema for this method consists of the following terms:
#
# ['country_name', 'hdi_category', 'indicator_name', 'references', 'year', 'values']
#
# The actions:
#
# ['CALCULATE', 'CATEGORISE', 'JOIN', 'NEW', 'ORDER', 'ORDER_NEW', 'ORDER_OLD', 'RENAME']
#
# The columns from your working data:
#
# ['GDP per capita - year of highest value', 'Indicator Name', 'Country', 'HDI category', 'Indicator Value', 'Reference Name', 'Reference']
#
#
# Data id: working_e3fa59b7-d01c-4091-be4a-13c38ecea257
# Original source: method.input_data
#
# ====  ========================================  ================  =========  ======================  =================  ================  ===========
#   ..    GDP per capita - year of highest value  Indicator Name    Country    HDI category              Indicator Value  Reference Name      Reference
# ====  ========================================  ================  =========  ======================  =================  ================  ===========
#    0                                      2005  HDI rank          Iceland    HIGH HUMAN DEVELOPMENT                  1  References 1              nan
#    1                                      2005  HDI rank          Norway     HIGH HUMAN DEVELOPMENT                  2  References 1              nan
#    2                                      2005  HDI rank          Australia  HIGH HUMAN DEVELOPMENT                  3  References 1              nan
# ====  ========================================  ================  =========  ======================  =================  ================  ===========
#
#
# Current method status: `Ready to Structure`

# %%
structure = {
    'country_name' : ['RENAME', 'Country'],
    'hdi_category' : ['RENAME', 'HDI category'],
    'indicator_name' : ['RENAME', 'Indicator Name'],
    'references' : ['RENAME', 'Reference'],
    'values' : ['RENAME', 'Indicator Value']
}
method.set_structure(**structure)

# %%
method.transform(overwrite_output=True)
FILENAME = "economic_perform_exercise"
method.save(directory, filename=FILENAME, overwrite=True)

# %%
method.input_data_morphs(ident)
# Out:
# [{'f51d7172-f298-4093-9500-d731ea3cada3': ['DEBLANK']},
#  {'023def89-66c6-4d31-9bfd-ec211078325b': ['DEDUPE']},
#  {'d6b64a53-595b-4b20-9337-1a755faaecb9': ['REBASE', [7]]},
#  {'8bebe07c-b5d3-4209-93d0-90b487512635': ['DELETE',
#    [188,
#     189,
#     190,
#     191,
#     192,
#     193,
#     194,
#     195,
#     196,
#     197,
#     198,
#     199,
#     200,
#     201,
#     202,
#     203,
#     204,
#     205,
#     206,
#     207,
#     208,
#     209,
#     210,
#     211,
#     212,
#     213,
#     214,
#     215,
#     216,
#     217,
#     218]]},
#  {'7fcb4af9-133a-4221-a831-e8568b0c6cec': ['RENAME',
#    ['HDI rank',
#     'Country',
#     'GDP - billions dollar US 2005',
#     'References 1',
#     'GDP - PPP billions dollar US 2005',
#     'References 2',
#     'GDP per capita - US 2005',
#     'References 3',
#     'GDP per capita - 2005 PPP dollar US 2005',
#     'References 4',
#     'GDP per capita - Annual growth rate(percent) 1975-2005',
#     'References 5',
#     'GDP per capita - Annual growth rate(percent) 1990-2005',
#     'References 6',
#     'GDP per capita - highest value during 1975-2005 2005 PPP US$',
#     'References 7',
#     'GDP per capita - year of highest value',
#     'Average annual change in consumer price index(percent) - 1990-2005',
#     'Average annual change in consumer price index(percent) - 2004-2005']]},
#  {'43f10966-d74e-4e1e-859b-144091d8c4ba': ['CATEGORISE',
#    [8, 79, 165],
#    ['HDI category']]},
#  {'b6a31201-4d64-499d-9c59-3a150f99554a': ['MELT',
#    [['References 6',
#      'GDP per capita - year of highest value',
#      'References 4',
#      'References 5',
#      'References 7',
#      'Country',
#      'HDI category',
#      'References 1',
#      'References 2',
#      'References 3'],
#     ['HDI rank',
#      'GDP - billions dollar US 2005',
#      'GDP - PPP billions dollar US 2005',
#      'GDP per capita - US 2005',
#      'GDP per capita - 2005 PPP dollar US 2005',
#      'GDP per capita - Annual growth rate(percent) 1975-2005',
#      'GDP per capita - Annual growth rate(percent) 1990-2005',
#      'GDP per capita - highest value during 1975-2005 2005 PPP US$',
#      'Average annual change in consumer price index(percent) - 1990-2005',
#      'Average annual change in consumer price index(percent) - 2004-2005']],
#    ['Indicator Name', 'Indicator Value']]},
#  {'e544db8c-36f6-4913-8c30-a069b44fe31c': ['MELT',
#    [['GDP per capita - year of highest value',
#      'Indicator Name',
#      'Country',
#      'HDI category',
#      'Indicator Value'],
#     ['References 1',
#      'References 2',
#      'References 3',
#      'References 4',
#      'References 5',
#      'References 6',
#      'References 7']],
#    ['Reference Name', 'Reference']]},
#  {'89452285-ad4a-4a07-9012-b5ed5d43389f': ['DEBLANK']}]

# %%
# %time method.validates
# Out:
# CPU times: user 3.5 s, sys: 24 ms, total: 3.53 s
# Wall time: 3.53 s
# True

# %%
source = "./SBC4D_course_2-2/output_fd38729c-b9a6-4d6e-8787-f7e9094dcd19.csv"

df = pd.read_csv(source)
df.head()
# Out:
#    year country_name            hdi_category indicator_name references values
# 0   NaN      Iceland  HIGH HUMAN DEVELOPMENT       HDI rank        NaN      1
# 1   NaN       Norway  HIGH HUMAN DEVELOPMENT       HDI rank        NaN      2
# 2   NaN    Australia  HIGH HUMAN DEVELOPMENT       HDI rank        NaN      3
# 3   NaN       Canada  HIGH HUMAN DEVELOPMENT       HDI rank        NaN      4
# 4   NaN      Ireland  HIGH HUMAN DEVELOPMENT       HDI rank        NaN      5

# %%
from pandas_schema import Column, Schema
from pandas_schema.validation import LeadingWhitespaceValidation, TrailingWhitespaceValidation, IsDtypeValidation, InListValidation

# Nous ne testerons que ces colonnes
columns = ["country_name", "hdi_category", "values"]
# Et ces catégories
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]

schema = Schema([
    Column("country_name", [LeadingWhitespaceValidation(), TrailingWhitespaceValidation()]),
    Column("hdi_category", [InListValidation(hdi_categories)]),
    Column("values", [IsDtypeValidation(np.dtype(float)), IsDtypeValidation(np.dtype(int))])
])

errors = schema.validate(df[columns])

print(F"Nombre d'erreurs :  {len(errors)}")
# Juste les 10 premiers
for error in errors[:10]:
    print(error)
# Out:
# Nombre d'erreurs :  152
# The column values has a dtype of object which is not a subclass of the required type float64
# The column values has a dtype of object which is not a subclass of the required type int64
# {row: 169, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 170, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 171, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 172, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 173, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 174, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 175, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 176, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)

# %%
for l in method.citation.split(","):
    print(l)
# Out:
# 2020-05-23
#  indicateur de performance economique des pays dans le monde
#  178bf12c4a9a41fd80e75976d37d3c2e44cf190f152623aad134e1ffbbfeb3db21245c37501bb87c513f8d3b82a9fa9aed7774aa8bda8e9c95bcc197a681b2a2
#  [input sources: ./HDR 2007-2008 Table 14.xlsx
#  c27bfe4a6dfe3f67706581f44dd246725caf22f48122443f0fea1f56657edfd978e34bfec09bbf634346cdea128569868d557153fe0747f53b8818c82c042488]
